# %%
% matplotlib inline
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
im = np.load('/home/wellbeier/cdata/augmented/0/04acab7636c4cf61d288a5962f15fa456b7bde31a021e5deedfbf51288e4001e_145.npy')

# %%
plt.imshow(im[..., 3:].max(-1))

# %%
plt.imshow(im[..., :3])

# %%
plt.imshow(im[..., :3])

# %%
plt.imshow(im[..., :3])

# %%
plt.imshow(im[..., :3])

# %%
plt.imshow(im[..., :3])
